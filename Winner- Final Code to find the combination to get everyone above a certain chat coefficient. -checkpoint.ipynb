# %%
Edgar	11	2
Kaz	18	2
Edwin	11	2
Fidel	8	2
William	10	2
Rylee	14	2
Noemi	12	2

# %%
import time
# Record the start time
start_time = time.time()
# [Agent, Chats, Days, Chats_Today_Variable]
# GoodToGo_.
# Final code to find the combination to get everyone above a certain chat coefficient. 
agents = [
    ["Edgar", 11, 2, 0],
    ["Fidel", 8, 2, 0],
    ["Edwin", 11, 2, 0],
    ["William", 10, 2, 0],
    ["Kaz", 18, 2, 0],
    ["Rylee", 14, 2, 0],
    ["Noemi", 12, 2, 0],
]

solutions = []

def calculate_coefficient(agent):
    return ((agent[1] + agent[3]) / (agent[2] + 1)) / (max((a[1] + a[3]) / (a[2] + 1) for a in agents)) * 100

for Edgar_chats_today in range(11): 
    for Fidel_chats_today in range(11):
        for Edwin_chats_today in range(11):
            for William_chats_today in range(11):
                for Kaz_chats_today in range(0, 11, 1):
                    for Rylee_chats_today in range(11):
                        for Noemi_chats_today in range(11):
                            agents[0][3] = Edgar_chats_today
                            agents[1][3] = Fidel_chats_today
                            agents[2][3] = Edwin_chats_today
                            agents[3][3] = William_chats_today
                            agents[4][3] = Kaz_chats_today
                            agents[5][3] = Rylee_chats_today
                            agents[6][3] = Noemi_chats_today

                            if all(calculate_coefficient(agent) >= 100 for agent in agents):
                                solutions.append({
                                    "Edgar": Edgar_chats_today,
                                    "Fidel": Fidel_chats_today,
                                    "Edwin": Edwin_chats_today,
                                    "William": William_chats_today,
                                    "Kaz": Kaz_chats_today,
                                    "Rylee": Rylee_chats_today,
                                    "Noemi": Noemi_chats_today
                                })

print("Solutions:")
for solution in solutions:
    print(solution)

# Record the end time
end_time = time.time()

# Calculate and print the elapsed time
elapsed_time = end_time - start_time
print(f"Time taken: {elapsed_time} seconds")
# Out:
# Solutions:
# {'Edgar': 7, 'Fidel': 10, 'Edwin': 7, 'William': 8, 'Kaz': 0, 'Rylee': 4, 'Noemi': 6}
# Time taken: 45.35717463493347 seconds

# %%
7		10	7	8	0	4	6

# %%
# [Agent, Chats, Days, Chats_Today_Variable]
# Final code to find the combination to get everyone above a certain chat coefficient. 
agents = [
    ["Edgar", 167, 23, 0],
    ["Fidel", 159, 22, 0],
    ["Edwin", 151, 21, 0],
    ["William", 152, 21, 0],
    ["Kaz", 152, 21, 0],
    ["Rylee", 145, 20, 0],
    ["Noemi", 129, 18, 0],
]

solutions = []

def calculate_coefficient(agent):
    return ((agent[1] + agent[3]) / (agent[2] + 1)) / (max((a[1] + a[3]) / (a[2] + 1) for a in agents)) * 100

for Edgar_chats_today in range(10):
    for Fidel_chats_today in range(0,10, 1):
        for Edwin_chats_today in range(10):
            for William_chats_today in range(10):
                for Kaz_chats_today in range(10):
                    for Rylee_chats_today in range(10):
                        for Noemi_chats_today in range(10):
                            agents[0][3] = Edgar_chats_today
                            agents[1][3] = Fidel_chats_today
                            agents[2][3] = Edwin_chats_today
                            agents[3][3] = William_chats_today
                            agents[4][3] = Kaz_chats_today
                            agents[5][3] = Rylee_chats_today
                            agents[6][3] = Noemi_chats_today

                            if all(calculate_coefficient(agent) >= 100 for agent in agents):
                                solutions.append({
                                    "Edgar": Edgar_chats_today,
                                    "Fidel": Fidel_chats_today,
                                    "Edwin": Edwin_chats_today,
                                    "William": William_chats_today,
                                    "Kaz": Kaz_chats_today,
                                    "Rylee": Rylee_chats_today,
                                    "Noemi": Noemi_chats_today
                                })

print("Solutions:")
for solution in solutions:
    print(solution)
# Out:
# Solutions:
# {'Edgar': 1, 'Fidel': 2, 'Edwin': 3, 'William': 2, 'Kaz': 2, 'Rylee': 2, 'Noemi': 4}

# %%
import time
# Record the start time
start_time = time.time()
# [Agent, Chats, Days, Chats_Today_Variable]
# GoodToGo_.
# Final code to find the combination to get everyone above a certain chat coefficient. 
agents = [
    ["Edgar", 11, 2, 0],
    ["Fidel", 8, 2, 0],
    ["Edwin", 11, 2, 0],
    ["William", 10, 2, 0],
    ["Kaz", 18, 2, 0],
    ["Rylee", 14, 2, 0],
    ["Noemi", 12, 2, 0],
]

solutions = []
coefficient = [0,0,0,0,0,0,0]


def calculate_coefficient(agent):
    return ((agent[1] + agent[3]) / (agent[2] + 1)) / (max((a[1] + a[3]) / (a[2] + 1) for a in agents)) * 100
    coef = ((agent[1] + agent[3]) / (agent[2] + 1)) / (max((a[1] + a[3]) / (a[2] + 1) for a in agents)) * 100
    

for Edgar_chats_today in range(11): 
    for Fidel_chats_today in range(11):
        for Edwin_chats_today in range(11):
            for William_chats_today in range(11):
                for Kaz_chats_today in range(0, 11, 1):
                    for Rylee_chats_today in range(11):
                        for Noemi_chats_today in range(11):
                            agents[0][3] = Edgar_chats_today
                            agents[1][3] = Fidel_chats_today
                            agents[2][3] = Edwin_chats_today
                            agents[3][3] = William_chats_today
                            agents[4][3] = Kaz_chats_today
                            agents[5][3] = Rylee_chats_today
                            agents[6][3] = Noemi_chats_today

                            if all(calculate_coefficient(agent) >= 100 for agent in agents):
                                solutions.append({
                                    "Edgar": Edgar_chats_today,
                                    "Fidel": Fidel_chats_today,
                                    "Edwin": Edwin_chats_today,
                                    "William": William_chats_today,
                                    "Kaz": Kaz_chats_today,
                                    "Rylee": Rylee_chats_today,
                                    "Noemi": Noemi_chats_today
                                })
                            
                            coefficient[0] = calculate_coefficient(agent[0]
                            coefficient[1] = calculate_coefficient(agent[0]
                            coefficient[] = calculate_coefficient(agent[0]
                            coefficient[0] = calculate_coefficient(agent[0]
                            coefficient[0] = calculate_coefficient(agent[0]
                            coefficient[0] = calculate_coefficient(agent[0]          
                            coefficient[0] = calculate_coefficient(agent[0]
                                                    

                            
                            print()
                            
                                
                        

print("Solutions:")
for solution in solutions:
    print(solution)

# Record the end time
end_time = time.time()

# Calculate and print the elapsed time
elapsed_time = end_time - start_time
print(f"Time taken: {elapsed_time} seconds")
# Out:
# Solutions:
# {'Edgar': 7, 'Fidel': 10, 'Edwin': 7, 'William': 8, 'Kaz': 0, 'Rylee': 4, 'Noemi': 6}
# Time taken: 49.142409324645996 seconds
